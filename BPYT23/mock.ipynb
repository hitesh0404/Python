# %%
y=["Mariya","Raj","Sonam","Lakshman","Riya"]
y=input("enter the name=")
if y:
    print ("print name successfulley")
else:
    print ("error")

 """ 
 select c.customernumber,customername,sum(priceEach*QuantityOrdered) 
 from 
        orders o 
join 
        orderdetails od  
using(ordernumber) 

join 
        customers c 
using(customernumber) 

group by 
        o.customernumber;
+----------------+------------------------------------+--------------------------------+
| customernumber | customername                       | sum(priceEach*QuantityOrdered) |
+----------------+------------------------------------+--------------------------------+
|            103 | Atelier graphique                  |                       22314.36 |
|            112 | Signal Gift Stores                 |                       80180.98 |
|            114 | Australian Collectors, Co.         |                      180585.07 |

"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 y=["Mariya","Raj","Sonam","Lakshman","Riya"]
# ----> 2 y=input("enter the name=",y)
#       3 if y:
#       4     print ("print name successfulley")
#
# TypeError: Kernel.raw_input() takes from 1 to 2 positional arguments but 3 were given
