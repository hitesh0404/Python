# %%
import re

# %%
r = re.compile("[hH]e")
print(r.findall("2234#$#$Hello he he "))
print(r.search("he he2234#$#$Hello"))
print(r.match("he2234#$#$hello"))
print(r.finditer("2234#$#$Hello he he "))
# Out:
# ['He', 'he', 'he']
# <re.Match object; span=(0, 2), match='he'>
# <re.Match object; span=(0, 2), match='he'>
# ...

# %%
# "2234#$#$Hello".find("he")
"2234#$#$Hello".find("He")
# Out:
# 8

# %%
for i in r.finditer("2234#$#$Hello he he "):
    print(i)
# Out:
# <re.Match object; span=(8, 10), match='He'>
# <re.Match object; span=(14, 16), match='he'>
# <re.Match object; span=(17, 19), match='he'>

# %%
re.findall("[hH]e",string="2234#$#$Hello he he ")
# Out:
# ['He', 'he', 'he']
