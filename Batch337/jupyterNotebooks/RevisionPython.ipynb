# %%
print("Hello world","This is print",end="\n\n\n\n",sep="----")
print("Hello world","With end and sep",end="\n\n\n\n",sep="----")
print("Hello world","Modified to see this example",end="\n\n\n\n",sep="----")
# Out:
# Hello world----This is print
#
#
#
# Hello world----With end and sep
#
#
#
# Hello world----Modified to see this example

# %%
d = input("Hello world")
print(type(d),d)
# Out:
# <class 'str'> 35

# %%
for i in range(12,10,-1):
    print("Hello",i)
# Out:
# Hello 12
# Hello 11

# %%
range(12,10,1)
# Out:
# range(12, 10)

# %%
for i in ["Hello","Hallo","Halllo"]:
    print(i)
# Out:
# Hello
# Hallo
# Halllo

# %%
i = 12
while(i>10):
    print("hello",i)
    i-=1
# Out:
# hello 12
# hello 11
