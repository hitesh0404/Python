# %%
num=4
with open("table.txt","w") as f:
    for i in range(1,11,1):
        f.write(f"{num} X {i} = {num*i}\n")

# %%
f = open("table.txt","w")

# %%
for i in range(1,11,1):
        f.write(f"{num} X {i} = {num*i}\n")

# %%
f.flush()
f.close()
