# %% [markdown]
# ### PART 1: QUESTIONS VIDEO (Questions Only - 25 min)
#
# **Format Note:** Each question is marked with difficulty level and type (Theory/Practical/Industry)
#
# ---
#
# #### **Theory Questions**
#
# **Q1. (Easy - Theory)** What is the difference between the `==` operator and the `is` operator in Python? When would you use each?
#
# **Q2. (Easy - Theory)** Explain what happens when you use the `+` operator on strings vs. numbers. Why are they different behaviors important?
#
# **Q3. (Medium - Theory)** What does "operator precedence" mean? Give an example where it matters in Python.
#
# **Q4. (Easy - Theory)** What are the primitive data types in Python? List them with one example for each.
#
# **Q5. (Medium - Theory)** Explain the concept of "type casting" in Python. Why is it necessary when working with data?
#
# **Q6. (Medium - Theory)** What is the difference between mutable and immutable data types? Give examples of each.
#
# **Q7. (Hard - Theory)** What is the `None` data type? How is it different from `0`, empty string `""`, or `False`?
#
# ---
#
# #### **Practical / Coding Questions**
#
# **Q8. (Easy - Practical)** What will this code output? Explain why.
# ```python
# a = 10
# b = 3
# print(a % b)
# print(a // b)
# print(a / b)
# ```
#
# **Q9. (Medium - Practical)** What will this code output? Trace through it step by step.
# ```python
# x = 5
# y = "5"
# print(x + y)
# ```
#
# **Q10. (Medium - Practical)** Predict the output:
# ```python
# a = 10
# b = 20
# c = 30
# result = a < b < c
# print(result)
# print(a > b or b < c)
# ```
#
# **Q11. (Easy - Practical)** What will be the output?
# ```python
# name = "DataScience"
# print(name[0])
# print(name[-1])
# print(name[2:5])
# ```
#
# **Q12. (Medium - Practical)** What does this code output? Why might this be useful for ML engineers?
# ```python
# numbers = "12345"
# print(type(numbers))
# numbers_int = int(numbers)
# print(type(numbers_int))
# print(numbers_int * 2)
# print(numbers * 2)
# ```
#
# ---
#
# #### **Common Mistakes & Tricky Scenarios**
#
# **Q13. (Medium - Common Mistake)** What's wrong with this code? What error will you get?
# ```python
# x = "Hello"
# y = 5
# result = x + y
# print(result)
# ```
# What should you do to fix it?
#
# **Q14. (Hard - Tricky)** Predict the output and explain:
# ```python
# a = [1, 2, 3]
# b = a
# b[0] = 99
# print(a)
# print(b)
# ```
# Why did `a` change?
#
# **Q15. (Hard - Industry Interview)** A colleague shows you this code during code review:
# ```python
# user_input = "42"
# result = user_input + 8
# print(result)
# ```
# What's the issue and what's the best practice for handling this in real applications (think about API responses or form data)?
#
# ---
#
# #### **Industry-Relevant Questions**
#
# **Q16. (Hard - ML Context)** In machine learning, you often work with datasets where features might be different types (strings, floats, integers). Explain why understanding type conversion is critical. How might a type mismatch cause issues in an ML pipeline?
#
# **Q17. (Medium - AI/ML)** Why would an AI engineer need to understand operator precedence? Give a scenario where getting this wrong could break a mathematical formula.

# %%
a = "hello"
b = "hello"
print(id(a),id(b))
a is b
# Out:
# 4439692208 4439692208
# True

# %%
a = 10
b = 10
print(id(a),id(b))

a is b
# Out:
# 4329812192 4329812192
# True

# %%
a = [1,2]
b = [1,2]
print(a == b)
print(a is b)
# Out:
# True
# False

# %%
print(2 + 2)
print("2" + "2")   # concatination
# Out:
# 4
# 22

# %%
2**(3*2)
# Out:
# 64

# %%
a = int()
b = int(input("enter second number"))
print(a,b)
print(a+b)
# Out:
# 2 2
# 4

# %%
e =

# %%
e = int(input("enter first number"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 e = int(input("enter first number"))
#
# ValueError: invalid literal for int() with base 10: '6hi'

# %%
e
# Out:
# 234

# %%
s = ['a','b','c']
s[0]  = "A"

# %%
s
# Out:
# ['A', 'b', 'c']

# %%
type(None)
# Out:
# NoneType

# %%
11//3
# Out:
# 3
